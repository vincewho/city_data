# %%
import os 
import pandas as pd

dataPath = '/Users/vincewho/Documents/Projects/python/city_data/data'
addData = []

for file in os.listdir(dataPath):
    data = pd.read_csv(dataPath + '/' + file)
    print(data.head())
    allData = addData.append(data)
allData = pd.concat(allData)

# concat all the files in the data dir and keep only one header
# Out:
# /Users/vincewho/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py:3524: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              Row ID  Year            Department Title  Payroll Department  \
# 0  6-2275746208ctFu  2016            General Services              3381.0
# 1  6-2275893216ctFu  2016  Public Works - Engineering              6201.0
# 2  6-2275906900ctFu  2016               Police (LAPD)              4301.0
# 3  6-2275925051ctFu  2016               Police (LAPD)              4302.0
# 4  6-2275958877ctFu  2016               Police (LAPD)              4301.0
#
#   Record Number                   Job Class Title Employment Type  \
# 0    2275746208                    Truck Operator       Full Time
# 1    2275893216    Civil Engineering Associate II       Full Time
# 2    2275906900                 Police Officer II       Full Time
# ...
